# %% [markdown]
# ## Supervised Leerning
#
# - Regression problem
#   - Linear Regression
#   - Lasso & Ridge Regression
#   - Decision Tree
#   - SVR
#   - KNN
#
# - Classification problem
#   - Logstic Regression
#   - Decision Tree
#   - Random Forest
#   - SVM
#   - KNN

# %% [markdown]
# ## DATA
#
# - Train Data
#   - Accounts for the largest proportion.
#   - The more the better the performance.
# - Validation Data
#   - Parameter verification.
# - Test Data
#   - Model performance testing.

# %% [markdown]
# ## Overfitting
# - A phenomenon in which a model is overtrained on specific training data.
# - Poor generalization performance.

# %% [markdown]
# ## Loss Function : ML  proceeds with the process of reducing Loss Fuc.
#
# - Regression : MSE
# - Classification : Cross Entropy
